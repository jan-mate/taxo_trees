# %% [markdown]
# # Instructions
#
# Copy paste these plot options into the 3rd cell in `make_taxo_tree.ipynb`
#
# Except the Homepage and wiki_taxo_trees, those options will be used in 4th cell

# %% [markdown]
# # Herbs and Spices

# %%
tab_title = 'Herbs & Spices'
urls_to_scrape = 'https://en.wikipedia.org/wiki/Plants_used_as_herbs_or_spices'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_width = 1900
plot_height = 7500
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2
y_range_offset_max = 12
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 396, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 396, 26, "edge", "Herbs and Spices", "images/squirrel_chili.webp", "It's pronounced /hɜːrb/ btw", "https://kochjar.me/trees/herbs_and_spices"],
    [3, 393, 14, "edge", "These are plants used to make food tastier!\nClick here to view the source wiki article :)", "images/squirrel_chili.webp", "This page is a sortable table of plants used as herbs and/or spices. This includes plants used as seasoning agents in foods or beverages (including teas), plants used for herbal medicine, and plants used as incense or similar ingested or partially ingested ritual components. ", "https://en.wikipedia.org/wiki/Plants_used_as_herbs_or_spices"],
]

# %% [markdown]
# # Nuts

# %%
tab_title = 'Nuts'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_culinary_nuts'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_width = 1900
plot_height = 4000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2
y_range_offset_max = 10
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 150, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 150, 26, "edge", "Nuts", "images/kokonutnut.jpg", "The coconut nut is a giant nut\nIf you eat too much, you'll get very fat\nNow, the coconut nut is a big, big nut\nBut this delicious nut is not a nut", "https://www.youtube.com/watch?v=PKQPey6L42M"],
    [3, 147.5, 14, "edge", "when i was 13 i loved hazelnuts, and one day i ate like 500g,\ni puked, and now i dont like hazel nuts.\nClick here to view the source wiki article :)", "images/hazelbrick.jpg", "someone should make a house out of hazelbrick", "https://en.wikipedia.org/wiki/List_of_culinary_nuts"],
]

# %% [markdown]
# # Forageable

# %%
tab_title = 'Forageables'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_forageable_plants'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_width = 1900
plot_height = 3500
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2
y_range_offset_max = 9
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 120, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 120, 26, "edge", "Commonly Foraged Plants", "images/atomic_shrimp.png", "I like Atomic Shrimp, they appreciate cheap/free food", "https://www.youtube.com/watch?v=r79B07E8IjE"],
    [3, 117, 14, "edge", "Don't use this as your foraging guide!\nYou will probably die! Beware that some plants\ncontain both edible and poisonus parts!\nClick here to view the source wiki article :)", "images/anarchoprimitivism.jpg", "This article is Good, you should check it out", "https://en.wikipedia.org/wiki/List_of_forageable_plants"],
]

# %% [markdown]
# # Flowers

# %%
tab_title = 'Flowers'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_edible_flowers'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_width = 1900
plot_height = 4000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2
y_range_offset_max = 8
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 141, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 141, 26, "edge", "Flowers you can eat", "images/flowerplate.jpg", "click here to view epic train drive through dutch tulip fields", "https://www.youtube.com/watch?v=WxepdHrY4Yk"],
    [3, 140, 14, "edge", "\nClick here to view the source wiki article :)", "images/violas.jpg", "Violas are so pretty!", "https://en.wikipedia.org/wiki/List_of_edible_flowers"],
]

# %% [markdown]
# # grass

# %%
tab_title = 'Seeds'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_edible_seeds'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_width = 1900
plot_height = 2000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2
y_range_offset_max = 8
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 64, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 64, 26, "edge", "Cereals and Pseudocereals", "images/grass.JPG", "click here for sauce about most food energy from grass(did you know 'sauce' is derived from salt? So are the followwing words: Salad, Sausage, Salary and Salsa)", "https://en.wikipedia.org/wiki/Poaceae"],
    [3, 61, 14, "edge", "grass is the most eaten food type (by energy),\nso stop saying grass is for vegan \nClick here to view the source wiki article :)\n* specifies that it's a pseudocereal", "images/squirrel_grass.jpg", "This wiki article is rly good btw!", "https://en.wikipedia.org/wiki/List_of_edible_seeds"],
]

# %% [markdown]
# # fruit

# %%
tab_title = 'Fruits'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_culinary_fruits'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_height = 20000
y_offset_internal = 0.6
y_offset_multiplier = 0.19
x_range_offset = 1.8
y_range_offset_max = 15
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 1238, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 1238, 26, "edge", "Fruit", "images/pbj.png", "If you like fruit you probably already know the YTber Wierd (fruit) Explorer, if not click here to view an epic video. It's ez top 10 best yt channel there is", "https://www.youtube.com/watch?v=FkKPpOomdpQ"],
    [3, 1232, 14, "edge", "There's so many epic fruit, but unfortunately\nthis tree isn't very readable and it's laggy.\nTry to familirize yourself with another tree first,\nand Chromium is also less laggy.\nClick here to view the source wiki article :)", "images/deadmansfingers.jpg", "I love Decaisnea fargesii, it's ripe at Halloween and looks like dead man's fingers, and also tasty", "https://en.wikipedia.org/wiki/List_of_culinary_fruits"],
]

# %% [markdown]
# # veggies

# %%
tab_title = 'Veggies'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_vegetables'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_height = 12000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 1.8
y_range_offset_max = 9
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 484.5, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 484.5, 26, "edge", "Vegetables", "images/large_daikon.jpg", "I've eaten Daikon 10 times independantly, on 5 of the occasions I got a mild headache, 3 of the times I got a severe headache. I don't have any known condition that otherwise causes headaches. Idk Daikon allergy baserate, but it's probably under 1/500, i estimate 1/10000, mostly cuz i googled radish (closely related) allergy is a thing. I don't have any other allergies, including those small red radishes. What is the probability im allergic? I don't have much field knowlegde but using bayes rule i estimate there's with more than 99% probability allergic, which is sad, cuz i rly like daikon :( but i tell myself it was nocebo so i can munch on daikon anyway :)", "https://www.youtube.com/watch?v=b7pzpgz5k4A"],
    [3, 482, 14, "edge", "Vegetables ≝ Edible-plant-part ∩ Fruitᶜ\nClick here to view the source wiki article :)", "images/veggie_squirrel.png", "This is the best definition of vegetable imo, but it's also a bit useless, cuz often times there's a subset that's better to say", "https://en.wikipedia.org/wiki/List_of_culinary_fruits"],
]

# %% [markdown]
# # leaf veggies

# %%
tab_title = 'Leafy Veggies'
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_leaf_vegetables'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_height = 15000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 1.8
y_range_offset_max = 12
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 819, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 819, 26, "edge", "Leaves", "images/coloredleaves.jpg", "these plants misclicked and used their \"prettyness\" evolution points on their leaves instead of flowers", "https://www.youtube.com/watch?v=ROPTP0yyroA"],
    [3, 817, 14, "edge", "\nClick here to view the source wiki article :)", "images/fern_fractal.png", "FERN fern ᶠᵉʳⁿ (Why isn't there unicode char for all sub/superscript letters‽ Atleast interobang is a unicode, and thats my fav symbol :)", "https://en.wikipedia.org/wiki/List_of_leaf_vegetables"],
]

# %% [markdown]
# # mammals

# %%
tab_title = "Danish Mammals"
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_mammals_of_Denmark'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'subphylum',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Animalia'
root_taxon_rank = 'kingdom'
plot_height = 5000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 1.8
y_range_offset_max = 10
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 190, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 190, 26, "edge", "Mammals of Denmark", "images/safi_kb2.jpeg", "Production of this taxonomic tree was delayed by this lovely mammal of Denmark*", "https://www.youtube.com/results?search_query=fennec%20fox"],
    [3, 187, 14, "edge", "Making Squirrels the danish national animal\nis the best decision dk has ever made\nClick here to view the source wiki article :)", "images/fennecfox.jpg", "The second best decision denmark ever made was to naturalize fennec foxes, except that never happened :´(", "https://en.wikipedia.org/wiki/List_of_leaf_vegetables"],
]

# %% [markdown]
# # dinos

# %%
tab_title = "Danish Birds"
urls_to_scrape = 'https://en.wikipedia.org/wiki/List_of_birds_of_Denmark' 
name = urls_to_scrape.split('/')[-1]
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"


rankings = [
    'kingdom',
    'subphylum',
    'order',
    'family',
    'genus',
    'species'
]

# root_taxon_name = 'Plantae'
root_taxon_name = 'Animalia'
root_taxon_rank = 'kingdom'
plot_height = 16000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2.5
y_range_offset_max = 13
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

info_text = """
A: Species recorded naturally at least once since 1950.  
B: Species recorded naturally between 1800–1949, but not since.  
C: Species introduced by humans with self-sustaining populations.  
* Rare species requiring approval by the Danish Rarities Committee (SU).
"""

nodes_manual = [
    [0.1, 834, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 834, 26, "edge", "Birds of Denmark", "images/hummingbird.jpg", "Why don't more ppl find it crazy that hummingbirds exists‽ They can fly backwards and upside down‽ They can flap with 80hz‽ they have heartbeat of 1200hz? They can weigh 2 grams‽", "https://en.wikipedia.org/wiki/Hummingbird"],
    [3, 830, 14, "edge", "My favorite dk dinosaur is probably Corvus Corone because\ni enjoy watching them play, and theyre friendly\nClick here to view the source wiki article :)", "images/rickandtwocrows.png", "This is me irl", "https://en.wikipedia.org/wiki/List_of_birds_of_Denmark"],
    [5.5, 830, 16, "edge", info_text, "images/hummingbird2.jpg", "More info on the source article", "https://en.wikipedia.org/wiki/List_of_birds_of_Denmark"],
]

# %% [markdown]
# # root

# %%
tab_title = 'Root Veggies'
urls_to_scrape = 'https://en.wikipedia.org/wiki/Root_vegetable'
name = urls_to_scrape.split('/')[-1]
tiny = False
original_data_filename = f"{name}.json" if not tiny else f"{name}_tiny.json"
scraped_data_filename = f"{name}_scraped.json"
output_plot_filename = f"{name}.html" if not tiny else f"{name}_tiny.html"

rankings = [
    'kingdom',
    'division',
    'order',
    'family',
    'genus',
    'species'
]

root_taxon_name = 'Plantae'
root_taxon_rank = 'kingdom'
plot_height = 4000
y_offset_internal = 0.5
y_offset_multiplier = 0.07
x_range_offset = 2.1
y_range_offset_max = 10
y_range_offset_min = 1
text_multiplier = 1
min_text = 15

horizontal_lines_manual = [
]

vertical_lines_manual = [
]

nodes_manual = [
    [0.1, 172, 4, "edge", "Go Back", "images/taxotree4.png", "", "https://kochjar.me/trees"],
    [3, 172, 26, "edge", "Root Vegetables", "images/buff_carrot.png", "Sad these are often dirty cuz i hate cleaning or even worse pe*ling... Seriously why do ppl peel potatoes‽", ""],
    [3, 171, 14, "edge", "\nClick here to view the source wiki article :)", "images/color_roots.jpg", "Cool how so many roots have pretty colors eventho they're not meant to be seen", "https://en.wikipedia.org/wiki/Root_vegetable"],
]

# %% [markdown]
# # hompage

# %%
import pandas as pd
from bokeh.models import ColumnDataSource, HoverTool, TapTool, CustomJS, WheelZoomTool, ResetTool, PanTool
from bokeh.plotting import figure, show, output_file

placeholder_image = "https://via.placeholder.com/150"
y_offset_internal = 0.3
y_offset_multiplier = 0.125
text_multiplier = 4
default_min_text_size = 14
plot_width = 1920
plot_height = 900

horizontal_lines = [
    [(0, 0), (1, 0)],
    [(1, -2.75), (2, -2.75)],
    [(1, 2.75), (2, 2.75)],
    [(2, 2.75), (3, 2.75)],
    [(2, -2.75), (3, -2.75)],
    [(3, 6.75), (3.5, 6.75)],
    [(3, 5.75), (3.5, 5.75)],
    [(3, 4.75), (3.5, 4.75)],
    [(3, 3.75), (3.5, 3.75)],
    [(3, 2.75), (3.5, 2.75)],
    [(3, 1.75), (3.5, 1.75)],
    [(3, 0.75), (3.5, 0.75)],
    [(3, -0.25), (3.5, -0.25)],
    [(3, -1.25), (3.5, -1.25)],
    [(3, -2.25), (3.5, -2.25)],
    [(3, -3.25), (3.5, -3.25)],
]

vertical_lines = [
    [(1, -2.75), (1, 2.75)],
    [(3, -1.25), (3, 6.75)],
    [(3, -2.25), (3, -3.25)],
]

# kochjar.me/spacer actually useful???
squirrel = """ 

                                                             _ 
                                                     . - ' `   ` } 
                                     _ . / )       /               } 
                                 . ' o       \ \   |               } 
                                 ' . _ _ _ . ' ` . \ \         { ` 
                                 / ` \ \ _ /     ,   ` .         } 
                                 \ \ = '   . - '       _ ` \ \     { 
                                   ` ' ` ;               ` ,     } 
                                         _ \ \               ;     } 
                                       / _ _ ` ; . . . - ' - - ' 
 """


nodes = [
    [0.05, 12.5, 6, "edge", "Source Code", "", "", "https://github.com/jan-mate/taxo_trees"],
    [1.5, 12.5, 36, "edge", "Wikipedia Taxonomic Trees", "", "", ""],
    [1.5, 9.5, 18, "edge", "12 interactive wiki taxonomic trees. You can\n\
hover and click on all* words to explore! You can\nalso zoom and move the trees around, for more\noptions click the buttons in top-right corner.\n\
All the data is from Wikipedia, and it certaintly\ncontains errors!\nChromium is recommended for this.", "", "", ""],

    [0.5, 0, 15, "node", "taxonomic trees", "images/taxotree4.png", "Interactive Taxonomic trees generated from Wikipedia", "https://kochjar.me/trees"],
    [1.5, 2.75, 15, "node", "plantae", "images/forsthaven.jpg", "Forst Botanisk Have in Charlottenlund is my fav collection of plants, go there :)", "https://en.wikipedia.org/wiki/Plant"],
    [1.5, -2.75, 15, "node", "animalia", "images/redpanda.jpeg", "red pandas so much cooler than fake pandas. if u prefer fake pandas ur not invited to my birthday party", "https://en.wikipedia.org/wiki/Animal"],
    [2.5, 2.75, 15, "node", "edible", "images/plants.jpg", "btw you can click here and see a huge tree of all edible plants :)", "/edible_plants"],
    [2.5, -2.75, 15, "node", "danish", "images/dk.png", "The 3rd best Nordic country (🇩🇰🇸🇪🇳🇴🇮🇸🇫🇮🇪🇪🇬🇱🇫🇴🇷🇺🇰🇵🇲🇰)", "https://en.wikipedia.org/wiki/Denmark"],
    [3.52, 6.75, 15, "edge", "fruit", "images/squirrel_mango.jpg", "Unlike much foods, fruit evolved to taste good for us, and we evolved to like it. Therefore it makes sense the tastiest food is fruit.", "/fruit"],
    [3.52, 5.75, 15, "edge", "veggies", "images/squirrel_pumpkin.png", "My favorite thing about being adult is you can eat veggies every day! And no one will stop you!", "/veggies"],
    [3.52, 4.75, 15, "edge", "nuts", "images/squirrel_fishing.png", "Top 10 nuts:\n10. Ginkgo nuts\n9.Chestnuts \n8. Pecan \n7. Hazelnut \n6. Cashew \n5. Brazil Nut\n4\n.Coconut \n3. Peanut \n2. Almond\n1. Walnut\n Honerable mention. cum", "/nuts"],
    [3.52, 3.75, 15, "edge", "(pseudo)cereals", "images/squirrel_cereal.jpg", "Just add milk and you have soup", "/cereals"],
    [3.52, 2.75, 15, "edge", "herbs ⋀ spices", "images/squirrel_chili.webp", "food must have been really bland back then since commited genocide to get spices", "/herbs_spices"],
    [3.52, 1.75, 15, "edge", "flowers", "images/flower_squirrel.jpg", "don't forget to eat the flowers", "/flowers"],
    [3.52, 0.75, 15, "edge", "forageable", "images/skeleton.jpg", "when you use this as ur foraging guide", "forageable"],
    [3.52, -0.25, 15, "edge", "roots", "images/squareroot.jpg", "√", "/roots"],
    [3.52, -1.25, 15, "edge", "leaf", "images/squirrel_eat_leaf.jpg", "i love spinach but like its much expensif and then u cook it, and it always leafs you wondering where 99% of it went :(", "/leaf"],
    [3.52, -2.25, 15, "edge", "dinosaurs", "images/goose.jpg", "The birds of Denmark", "/dkbirds"],
    [3.52, -3.25, 15, "edge", "titty animals", "images/squirrelske.jpg", "The mammals of Denmark", "/dkmammals"],

    [-15, 15, -60, "node", squirrel, "images/bobo.jpg", "ascii art by Joan G. Stark", "https://www.youtube.com/watch?v=1CIMGTO6aFc"],
]


def draw_manual_tree(horizontal_lines, vertical_lines, nodes, output_plot_filename="homepage.html"):
    nodes_df = pd.DataFrame(nodes, columns=['x', 'y', 'base_text_size', 'type', 'text', 'hover_img', 'hover_text', 'link'])
    max_depth = max(max(line[0][0], line[1][0]) for line in horizontal_lines + vertical_lines)
    
    xs_lines, ys_lines, line_widths = [], [], []
    for line in horizontal_lines + vertical_lines:
        xs_lines.append([line[0][0], line[1][0]])
        ys_lines.append([line[0][1], line[1][1]])
        depth = line[0][0]
        size_multiplier = max_depth - depth
        line_widths.append(3 * size_multiplier + 2)
    
    lines_source = ColumnDataSource(data=dict(
        xs=xs_lines,
        ys=ys_lines,
        line_widths=line_widths,
        original_line_widths=line_widths.copy()
    ))

    nodes_with_hover = nodes_df[(nodes_df['hover_img'] != "") | (nodes_df['hover_text'] != "")]
    nodes_without_hover = nodes_df[(nodes_df['hover_img'] == "") & (nodes_df['hover_text'] == "")]
    
    text_size_with_hover = [
        f"{base_size + (max_depth - x) * text_multiplier}px" 
        for x, base_size in zip(nodes_with_hover['x'], nodes_with_hover['base_text_size'])
    ]
    text_size_without_hover = [
        f"{base_size + (max_depth - x) * text_multiplier}px" 
        for x, base_size in zip(nodes_without_hover['x'], nodes_without_hover['base_text_size'])
    ]
    
    y_offset_scaled_with_hover = [
        (max_depth - x) * y_offset_multiplier + y_offset_internal if t == "node" else 0
        for x, t in zip(nodes_with_hover['x'], nodes_with_hover['type'])
    ]
    y_offset_scaled_without_hover = [
        (max_depth - x) * y_offset_multiplier + y_offset_internal if t == "node" else 0
        for x, t in zip(nodes_without_hover['x'], nodes_without_hover['type'])
    ]
    
    text_align_with_hover = nodes_with_hover['type'].apply(lambda t: 'left' if t == "edge" else 'center')
    text_align_without_hover = nodes_without_hover['type'].apply(lambda t: 'left' if t == "edge" else 'center')
    
    labels_with_hover_source = ColumnDataSource(data=dict(
        x=nodes_with_hover['x'], 
        y=nodes_with_hover['y'] + y_offset_scaled_with_hover,
        base_y=nodes_with_hover['y'],
        text=nodes_with_hover['text'], 
        hover_img=nodes_with_hover['hover_img'],
        hover_text=nodes_with_hover['hover_text'], 
        link=nodes_with_hover['link'],
        depth=nodes_with_hover['x'], 
        text_align=text_align_with_hover,
        text_size=text_size_with_hover,
        original_text_size=text_size_with_hover,
        original_y_offset=y_offset_scaled_with_hover
    ))
    
    labels_without_hover_source = ColumnDataSource(data=dict(
        x=nodes_without_hover['x'], 
        y=nodes_without_hover['y'] + y_offset_scaled_without_hover,
        base_y=nodes_without_hover['y'],
        text=nodes_without_hover['text'], 
        hover_img=nodes_without_hover['hover_img'],
        hover_text=nodes_without_hover['hover_text'], 
        link=nodes_without_hover['link'],
        depth=nodes_without_hover['x'], 
        text_align=text_align_without_hover,
        text_size=text_size_without_hover,
        original_text_size=text_size_without_hover,
        original_y_offset=y_offset_scaled_without_hover
    ))
    
    p = figure(title="",
        background_fill_color='black',
        border_fill_color='black',
        outline_line_color='black',
        sizing_mode="stretch_both",
        x_range=(0, max_depth + 0.35), y_range=(-5, 13))
    
    p.multi_line(xs='xs', ys='ys', source=lines_source, line_color="white", line_width='line_widths')
    
    # Create two separate text renderers
    text_renderer_with_hover = p.text(
        x='x', y='y', text='text', source=labels_with_hover_source,
        text_color='white', text_font_size='text_size', text_baseline='middle', text_align='text_align'
    )
    
    text_renderer_without_hover = p.text(
        x='x', y='y', text='text', source=labels_without_hover_source,
        text_color='white', text_font_size='text_size', text_baseline='middle', text_align='text_align'
    )
    
    # Apply HoverTool only to text_renderer_with_hover
    callback = CustomJS(args=dict(source=labels_with_hover_source), code="""
        const selected_index = source.selected.indices[0];
        if (selected_index != null) {
            const url = source.data['link'][selected_index];
            if (url) {
                let newUrl;
                if (url.startsWith('http://') || url.startsWith('https://')) {
                    newUrl = url;
                } else {
                    const baseUrl = window.location.href.substring(0, window.location.href.lastIndexOf('/') + 1);
                    newUrl = new URL(url, baseUrl).href;
                }
                window.open(newUrl, "_blank");
            }
        }
        source.selected.indices = [];
    """)

    tap_tool = TapTool(callback=callback, renderers=[text_renderer_with_hover])
    p.add_tools(tap_tool)
    
    TOOLTIPS = """
    <div style="width: 350px; background-color: rgba(221, 221, 221, 1); padding: 10px;">
        <div style="text-align: center;">
            <img src="@hover_img" alt=""
                style="display: block; margin: 0 auto; max-height: 300px; max-width: 300px; height: auto; width: auto;" 
                border="0">
        </div>
        <div style="text-align: center; margin-top: 15px;">
            <span style="font-size: 16px; color: #000000;">@hover_text</span>
        </div>
    </div>
    """

    hover_tool = HoverTool(tooltips=TOOLTIPS, renderers=[text_renderer_with_hover], point_policy="follow_mouse")
    p.add_tools(hover_tool)
    
    zoom_callback = CustomJS(args=dict(
        labels_with_hover_source=labels_with_hover_source,
        labels_without_hover_source=labels_without_hover_source,
        lines_source=lines_source,
        plot=p
    ), code="""
        const x_range = plot.x_range.end - plot.x_range.start;
        

        const labels_with = labels_with_hover_source.data;
        const depths_with = labels_with['depth'];
        const n_labels_with = depths_with.length;
        for (let i = 0; i < n_labels_with; i++) {
            const depth = depths_with[i];
            const threshold = 35 - depth * 3;
            let text_size;
            if (x_range > threshold) {
                text_size = '0px';
            } else {
                text_size = labels_with['original_text_size'][i];
            }
            labels_with['text_size'][i] = text_size;
            labels_with['y'][i] = labels_with['base_y'][i] + labels_with['original_y_offset'][i];
        }
        labels_with_hover_source.change.emit();
        
        
        const labels_without = labels_without_hover_source.data;
        const depths_without = labels_without['depth'];
        const n_labels_without = depths_without.length;
        for (let i = 0; i < n_labels_without; i++) {
            const depth = depths_without[i];
            const threshold = 5;
            let text_size;
            if (x_range > threshold) {
                text_size = '0px';
            } else {
                text_size = labels_without['original_text_size'][i];
            }
            labels_without['text_size'][i] = text_size;
            labels_without['y'][i] = labels_without['base_y'][i] + labels_without['original_y_offset'][i];
        }
        labels_without_hover_source.change.emit();
    
        
        const lines_data = lines_source.data;
        const line_widths = lines_data['line_widths'];
        const original_line_widths = lines_data['original_line_widths'];
        const n_lines = line_widths.length;
        const scaling_factor = Math.max(0.1, Math.min(1, 800 / x_range));
        for (let i = 0; i < n_lines; i++) {
            const original_width = original_line_widths[i];
            let new_width = original_width * scaling_factor;
            line_widths[i] = new_width;
        }
        lines_source.change.emit();
    """)
    
    p.x_range.js_on_change('start', zoom_callback)
    p.x_range.js_on_change('end', zoom_callback)
    p.y_range.js_on_change('start', zoom_callback)
    p.y_range.js_on_change('end', zoom_callback)

    p.grid.visible = False
    p.axis.visible = False
    
    wheel_zoom_tool = WheelZoomTool()
    reset_tool = ResetTool()
    pan_tool = PanTool()

    p.toolbar.tools = [pan_tool, wheel_zoom_tool, tap_tool, hover_tool, reset_tool]

    p.toolbar.logo = None
    p.toolbar.active_scroll = wheel_zoom_tool
    p.toolbar.active_drag = pan_tool
    
    output_file(output_plot_filename)
    show(p)

draw_manual_tree(horizontal_lines, vertical_lines, nodes)

# %% [markdown]
# # wiki_taxo_trees

# %%
placeholder_image = "https://via.placeholder.com/150"
y_offset_internal = 1
y_offset_multiplier = 0.125
text_multiplier = 4
default_min_text_size = 25
plot_width = 100
plot_height = 100

horizontal_lines = [
    [(0, 0), (1, 0)],
    [(1, -2.75), (1.25, -2.75)],
    [(1, 2.75), (1.25, 2.75)],
]

vertical_lines = [
    [(1, -2.75), (1, 2.75)],
]


nodes = [
    [0.85, 0, default_min_text_size, "node", "wiki", "images/taxotree4.png", "Interactive Taxonomic trees generated from Wikipedia", "https://kochjar.me/trees"],
    [1.25, 2.75, default_min_text_size, "edge", "taxo", "images/forsthaven.jpg", "Forst Botanisk Have in Charlottenlund is my fav collection of plants, go there :)", "https://en.wikipedia.org/wiki/Plant"],
    [1.25, -2.75, default_min_text_size, "edge", "trees", "images/redpanda.jpeg", "red pandas so much cooler than fake pandas. if u prefer fake pandas ur not invited to my birthday party", "https://en.wikipedia.org/wiki/Animal"],

]
